# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd

df = pd.read_excel('data/movieData.xlsx')
df
# Out:
#                    영화        감독                            배우      코드번호  \
# 0            태극기 휘날리며       강제규                장동건,원빈,이은주,공형진  20030371
# 1                 트로이   볼프강 페터슨       브래드 피트,올랜도 블룸,에릭 바나,숀 빈  20040555
# 2         내 머리 속의 지우개       이재한               정우성,손예진,백종학,이선진  20040673
# 3              귀신이 산다       김상진               차승원,장서희,장항선,손태영  20040649
# 4                투모로우  롤랜드 에머리히   데니스 퀘이드,제이크 질렌할,이안 홀름,에미 로섬  20040490
# ..                ...       ...                           ...       ...
# 845               젠틀맨     가이 리치     매튜 맥커너히,휴 그랜트,콜린 파렐,찰리 허냄  20193526
# 846  극장판 미니특공대 공룡왕 디노       이영준               신용우,엄상현,양정화,이소영  20192984
# 847             에어로너츠      톰 하퍼  펠리시티 존스,에디 레드메인,히메쉬 파텔,톰 커트니  20205481
# 848         엽문4 더 파이널       엽위신            견자단,스캇 애드킨스,진국곤,오월  20205262
# 849    밤쉘 세상을 바꾼 폭탄선언     제이 로치    샤를리즈 테론,니콜 키드먼,마고 로비,존 리스고  20204644
#
#                    장르                                     상영타입          매출액  \
# ...

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# ## 모델링

# %% [markdown]
# ## 시각화
